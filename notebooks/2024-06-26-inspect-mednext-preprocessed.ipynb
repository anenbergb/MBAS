# %%
import pickle
import os

# %%
plans_pickle_path = "/home/bryan/data/mednext_preprocessed/Task501_MBAS/nnUNetPlansv2.1_trgSp_1x1x1_plans_3D.pkl"
# plans_pickle_path_256 = "/home/bryan/data/mednext_preprocessed/Task501_MBAS/nnUNetPlansv2.1_trgSp_1x1x1_patch20x256x256_plans_3D.pkl"

# %%
with open(plans_pickle_path, 'rb') as file:
    plans_pickle = pickle.load(file)

# %%
with open(plans_pickle_path_256, 'rb') as file:
    plans_pickle_256 = pickle.load(file)

# %%
plans_pickle
# Out:
# {'num_stages': 1,
#  'num_modalities': 1,
#  'modalities': {0: 'LGE_MRI'},
#  'normalization_schemes': OrderedDict([(0, 'nonCT')]),
#  'dataset_properties': {'all_sizes': [(44, 638, 638),
#    (44, 574, 574),
#    (44, 638, 638),
#    (44, 638, 638),
#    (44, 574, 574),
#    (44, 574, 574),
#    (44, 574, 574),
#    (44, 638, 638),
#    (44, 638, 638),
#    (44, 573, 574),
#    (44, 574, 574),
#    (44, 574, 574),
#    (44, 574, 574),
#    (44, 574, 574),
#    (44, 638, 638),
#    (44, 638, 638),
#    (44, 638, 638),
#    (44, 638, 638),
#    (44, 638, 638),
#    (44, 574, 574),
#    (44, 574, 574),
#    (44, 574, 574),
#    (44, 638, 638),
#    (44, 638, 638),
#    (44, 638, 638),
#    (44, 638, 638),
#    (44, 574, 574),
#    (44, 574, 574),
#    (44, 638, 638),
#    (44, 570, 574),
#    (44, 638, 638),
#    (44, 574, 574),
#    (44, 574, 574),
#    (44, 568, 574),
#    (44, 638, 638),
#    (44, 638, 638),
#    (44, 574, 574),
#    (44, 638, 638),
#    (44, 574, 574),
# ...
